# %% [markdown]
# ## Chest CT Registration
#
# Authors: **Muhammad Zain Amin**, **Mohammad Imran Hossain**
# <br>
# Erasmus Mundus Joint Master Degree in Medical Imaging and Applications (MAIA)
# <br>
# University of Girona, Spain

# %%
# Install Dependencies
# !pip install simpleITK
# !pip install xlsxwriter
# !pip install voxelmorph
# Out:
# Requirement already satisfied: simpleITK in /usr/local/lib/python3.10/dist-packages (2.3.1)
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.10/dist-packages (3.1.9)
# Requirement already satisfied: voxelmorph in /usr/local/lib/python3.10/dist-packages (0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (23.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (0.19.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (1.11.4)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (4.0.2)
# Requirement already satisfied: neurite>=0.2 in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (4.66.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (1.2.2)
# Requirement already satisfied: pystrum>=0.2 in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->voxelmorph) (67.7.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neurite>=0.2->voxelmorph) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neurite>=0.2->voxelmorph) (3.2.0)

# %%
# Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib
from scipy.ndimage import zoom
import neurite as ne
import voxelmorph as vxm
import keras.backend as K
import tensorflow as tf
import time
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
new_z_dim = 128
data_file = "/content/drive/MyDrive/MIRA_Final_Project/dataset/results_affine_bspline_preprocessed/"
data = []
list_id = [1, 2, 3, 4]


for val_i in list_id:

  name = "copd" + str(val_i)
  print(name)

  inhale_imgPath = data_file + 'copd{}/'.format(val_i) + '{0}/seg_{0}_iBHCT.nii.gz'.format(name)
  exhale_imgPath = data_file + 'copd{}/'.format(val_i) + '{0}/reg_{0}_BHCT.nii.gz'.format(name)

  inhale_data = nib.load(inhale_imgPath).get_fdata()
  exhale_data = nib.load(exhale_imgPath).get_fdata()

  mean = np.mean(inhale_data[np.nonzero(inhale_data)])
  std = np.std(inhale_data[np.nonzero(inhale_data)])
  inhale_data = (inhale_data - mean) / std

  mean = np.mean(exhale_data[np.nonzero(exhale_data)])
  std = np.std(exhale_data[np.nonzero(exhale_data)])
  exhale_data = (exhale_data - mean) / std

  factor = new_z_dim / inhale_data.shape[2]

  if(val_i == 0):
    new_inhale = np.expand_dims(zoom(inhale_data, (1, 1, factor)), axis=0)
    new_exhale = np.expand_dims(zoom(exhale_data, (1, 1, factor)), axis=0)
  else :
    new_inhale = np.expand_dims(zoom(inhale_data, (0.5, 0.5, factor)), axis=0)
    new_exhale = np.expand_dims(zoom(exhale_data, (0.5, 0.5, factor)), axis=0)

  data.append(np.concatenate((new_inhale, new_exhale), axis=0))

np.save('/content/drive/MyDrive/MIRA_Final_Project/dataset/saved_data/affine_bspline_VM.npy', data)
# Out:
# copd1
# copd2
# copd3
# copd4

# %%
# load data numpy file
data = np.load('/content/drive/MyDrive/MIRA_Final_Project/dataset/saved_data/affine_bspline_VM.npy')
print(data.shape)

# split into training and validation
split_per = 75
train_split = int((split_per/100) * len(data))
data_train = data[:train_split, ...]
data_val = data[train_split:, ...]
print('train shape:', data_train.shape)
# Out:
# (4, 2, 256, 256, 128)
# train shape: (3, 2, 256, 256, 128)

# %%
BATCH_SIZE_ = 1
def vxm_data_generator(x_data, batch_size):
    # preliminary sizing
    vol_shape = x_data.shape[2:]
    ndims = len(vol_shape)

    # prepare a zero array the size of the deformation.
    zero_phi = np.zeros([batch_size, *vol_shape, ndims])

    while True:
        # prepare inputs
        idx = np.random.randint(0, x_data.shape[0], size=batch_size)
        fixed_images = x_data[idx, 0, ..., np.newaxis]
        moving_images = x_data[idx, 1, ..., np.newaxis]
        inputs = [moving_images, fixed_images]
        outputs = [fixed_images, zero_phi]
        yield inputs, outputs

# %%
# create the data generator
train_generator = vxm_data_generator(data_train, BATCH_SIZE_)

# visualize a sample
input_sample, output_sample = next(train_generator)

# Rotate the images by 90 degrees clockwise
input_sample_rotated = [np.rot90(sample, k=1, axes=(1, 2)) for sample in input_sample]
output_sample_rotated = [np.rot90(sample, k=1, axes=(1, 2)) for sample in output_sample]

slices_2d = [
    input_sample_rotated[1][0, :, :, 60, 0],
    input_sample_rotated[0][0, :, :, 60, 0],
]

titles = ['Segmented Exhale Image [Moving Image]', 'Segmented Inhale Image [Fixed Image]']
ne.plot.slices(slices_2d, titles=titles, cmaps=['gray'], do_colorbars=True)
# Out:
# (<Figure size 1500x750 with 4 Axes>,
#  array([<Axes: title={'center': 'Segmented Exhale Image [Moving Image]'}>,
#         <Axes: title={'center': 'Segmented Inhale Image [Fixed Image]'}>],
#        dtype=object))

# %%
# configure unet features
nb_features = [
    [32, 32, 32, 32],         # encoder features
    [32, 32, 32, 32, 32, 16]  # decoder features
]

# build model using VxmDense
inshape = data_train.shape[2:]
vxm_model = vxm.networks.VxmDense(inshape, nb_features, int_steps=0)

# %%
print('input shape: ', ', '.join([str(t.shape) for t in vxm_model.inputs]))
print('output shape:', ', '.join([str(t.shape) for t in vxm_model.outputs]))
# Out:
# input shape:  (None, 256, 256, 128, 1), (None, 256, 256, 128, 1)
# output shape: (None, 256, 256, 128, 1), (None, 256, 256, 128, 3)

# %%
# voxelmorph has a variety of custom loss classes
losses = [vxm.losses.MSE().loss, vxm.losses.Grad('l2').loss]

# we have to balance the two losses by a hyper-parameter
lambda_param = 0.05
loss_weights = [1, lambda_param]

# %%
vxm_model.compile(optimizer='Adam', loss=losses, loss_weights=loss_weights)

# %%
# train the model
nb_epochs = 100

earlyStopping = EarlyStopping(monitor='loss', patience=10, verbose=1, mode='min')
mcp_save = ModelCheckpoint('/content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_{0}_test_{1}_epoch_{2}.keras'.format(split_per, (100-split_per),nb_epochs), save_best_only=True, monitor='loss', mode='min', verbose=1)

reduce_lr_loss = ReduceLROnPlateau(monitor='loss', factor=0.1, patience=4, verbose=1, min_delta=1e-4, mode='min')
steps_per_epoch = data_train.shape[0]

start_time = time.time()
hist = vxm_model.fit(train_generator, epochs=nb_epochs, steps_per_epoch=steps_per_epoch, verbose=1, callbacks=[mcp_save, reduce_lr_loss]);
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 1/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1793 - vxm_dense_transformer_loss: 0.1793 - vxm_dense_flow_loss: 3.0035e-04
# Epoch 1: loss improved from inf to 0.17929, saving model to /content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_75_test_25_epoch_100.keras
# 3/3 [==============================] - 13s 2s/step - loss: 0.1793 - vxm_dense_transformer_loss: 0.1793 - vxm_dense_flow_loss: 3.0035e-04 - lr: 0.0010
# Epoch 2/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0798 - vxm_dense_transformer_loss: 0.0798 - vxm_dense_flow_loss: 8.1703e-04
# Epoch 2: loss improved from 0.17929 to 0.07982, saving model to /content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_75_test_25_epoch_100.keras
# 3/3 [==============================] - 6s 2s/step - loss: 0.0798 - vxm_dense_transformer_loss: 0.0798 - vxm_dense_flow_loss: 8.1703e-04 - lr: 0.0010
# Epoch 3/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3415 - vxm_dense_transformer_loss: 0.3414 - vxm_dense_flow_loss: 0.0025
# Epoch 3: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.3415 - vxm_dense_transformer_loss: 0.3414 - vxm_dense_flow_loss: 0.0025 - lr: 0.0010
# Epoch 4/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0804 - vxm_dense_transformer_loss: 0.0804 - vxm_dense_flow_loss: 0.0012
# Epoch 4: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.0804 - vxm_dense_transformer_loss: 0.0804 - vxm_dense_flow_loss: 0.0012 - lr: 0.0010
# Epoch 5/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1531 - vxm_dense_transformer_loss: 0.1530 - vxm_dense_flow_loss: 0.0022
# Epoch 5: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.1531 - vxm_dense_transformer_loss: 0.1530 - vxm_dense_flow_loss: 0.0022 - lr: 0.0010
# Epoch 6/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3253 - vxm_dense_transformer_loss: 0.3250 - vxm_dense_flow_loss: 0.0061
# Epoch 6: loss did not improve from 0.07982
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 3/3 [==============================] - 6s 2s/step - loss: 0.3253 - vxm_dense_transformer_loss: 0.3250 - vxm_dense_flow_loss: 0.0061 - lr: 0.0010
# Epoch 7/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1347 - vxm_dense_transformer_loss: 0.1345 - vxm_dense_flow_loss: 0.0037
# Epoch 7: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.1347 - vxm_dense_transformer_loss: 0.1345 - vxm_dense_flow_loss: 0.0037 - lr: 1.0000e-04
# Epoch 8/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1334 - vxm_dense_transformer_loss: 0.1332 - vxm_dense_flow_loss: 0.0037
# Epoch 8: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.1334 - vxm_dense_transformer_loss: 0.1332 - vxm_dense_flow_loss: 0.0037 - lr: 1.0000e-04
# Epoch 9/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1502 - vxm_dense_transformer_loss: 0.1500 - vxm_dense_flow_loss: 0.0038
# Epoch 9: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.1502 - vxm_dense_transformer_loss: 0.1500 - vxm_dense_flow_loss: 0.0038 - lr: 1.0000e-04
# Epoch 10/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2407 - vxm_dense_transformer_loss: 0.2405 - vxm_dense_flow_loss: 0.0056
# Epoch 10: loss did not improve from 0.07982
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 3/3 [==============================] - 6s 2s/step - loss: 0.2407 - vxm_dense_transformer_loss: 0.2405 - vxm_dense_flow_loss: 0.0056 - lr: 1.0000e-04
# Epoch 11/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1485 - vxm_dense_transformer_loss: 0.1483 - vxm_dense_flow_loss: 0.0041
# Epoch 11: loss did not improve from 0.07982
# 3/3 [==============================] - 7s 2s/step - loss: 0.1485 - vxm_dense_transformer_loss: 0.1483 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-05
# Epoch 12/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2219 - vxm_dense_transformer_loss: 0.2217 - vxm_dense_flow_loss: 0.0058
# Epoch 12: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.2219 - vxm_dense_transformer_loss: 0.2217 - vxm_dense_flow_loss: 0.0058 - lr: 1.0000e-05
# Epoch 13/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1483 - vxm_dense_transformer_loss: 0.1480 - vxm_dense_flow_loss: 0.0041
# Epoch 13: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.1483 - vxm_dense_transformer_loss: 0.1480 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-05
# Epoch 14/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1303 - vxm_dense_transformer_loss: 0.1301 - vxm_dense_flow_loss: 0.0041
# Epoch 14: loss did not improve from 0.07982
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 3/3 [==============================] - 6s 2s/step - loss: 0.1303 - vxm_dense_transformer_loss: 0.1301 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-05
# Epoch 15/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1303 - vxm_dense_transformer_loss: 0.1301 - vxm_dense_flow_loss: 0.0041
# Epoch 15: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.1303 - vxm_dense_transformer_loss: 0.1301 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-06
# Epoch 16/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 16: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-06
# Epoch 17/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1656 - vxm_dense_flow_loss: 0.0043
# Epoch 17: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1656 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-06
# Epoch 18/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 18: loss did not improve from 0.07982
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-06
# Epoch 19/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 19: loss did not improve from 0.07982
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-07
# Epoch 20/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025
# Epoch 20: loss improved from 0.07982 to 0.07440, saving model to /content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_75_test_25_epoch_100.keras
# 3/3 [==============================] - 6s 2s/step - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025 - lr: 1.0000e-07
# Epoch 21/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 21: loss did not improve from 0.07440
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-07
# Epoch 22/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 22: loss did not improve from 0.07440
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-07
# Epoch 23/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025
# Epoch 23: loss improved from 0.07440 to 0.07439, saving model to /content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_75_test_25_epoch_100.keras
# 3/3 [==============================] - 6s 2s/step - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025 - lr: 1.0000e-07
# Epoch 24/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 24: loss did not improve from 0.07439
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-07
# Epoch 25/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 25: loss did not improve from 0.07439
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-08
# Epoch 26/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 26: loss did not improve from 0.07439
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-08
# Epoch 27/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043
# Epoch 27: loss did not improve from 0.07439
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-08
# Epoch 28/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043
# Epoch 28: loss did not improve from 0.07439
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-08
# Epoch 29/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 29: loss did not improve from 0.07439
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-09
# Epoch 30/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 30: loss did not improve from 0.07439
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-09
# Epoch 31/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 31: loss did not improve from 0.07439
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-09
# Epoch 32/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025
# Epoch 32: loss improved from 0.07439 to 0.07439, saving model to /content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_75_test_25_epoch_100.keras
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 3/3 [==============================] - 6s 2s/step - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025 - lr: 1.0000e-09
# Epoch 33/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 33: loss improved from 0.07439 to 0.05663, saving model to /content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_75_test_25_epoch_100.keras
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-10
# Epoch 34/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 34: loss did not improve from 0.05663
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-10
# Epoch 35/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 35: loss did not improve from 0.05663
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-10
# Epoch 36/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0922 - vxm_dense_transformer_loss: 0.0920 - vxm_dense_flow_loss: 0.0026
# Epoch 36: loss did not improve from 0.05663
# 3/3 [==============================] - 6s 2s/step - loss: 0.0922 - vxm_dense_transformer_loss: 0.0920 - vxm_dense_flow_loss: 0.0026 - lr: 1.0000e-10
# Epoch 37/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 37: loss did not improve from 0.05663
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-10
# Epoch 38/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 38: loss did not improve from 0.05663
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-11
# Epoch 39/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041
# Epoch 39: loss did not improve from 0.05663
# 3/3 [==============================] - 6s 2s/step - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-11
# Epoch 40/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041
# Epoch 40: loss did not improve from 0.05663
# 3/3 [==============================] - 6s 2s/step - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-11
# Epoch 41/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 41: loss did not improve from 0.05663
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-11
# Epoch 42/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 42: loss did not improve from 0.05663
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-12
# Epoch 43/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 43: loss did not improve from 0.05663
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-12
# Epoch 44/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023
# Epoch 44: loss improved from 0.05663 to 0.03887, saving model to /content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_75_test_25_epoch_100.keras
# 3/3 [==============================] - 6s 2s/step - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023 - lr: 1.0000e-12
# Epoch 45/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 45: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-12
# Epoch 46/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 46: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-12
# Epoch 47/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043
# Epoch 47: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-12
# Epoch 48/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 48: loss did not improve from 0.03887
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000001044244145e-13.
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-12
# Epoch 49/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041
# Epoch 49: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-13
# Epoch 50/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 50: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-13
# Epoch 51/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 51: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-13
# Epoch 52/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 52: loss did not improve from 0.03887
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1.0000001179769417e-14.
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-13
# Epoch 53/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 53: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-14
# Epoch 54/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 54: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-14
# Epoch 55/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 55: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-14
# Epoch 56/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025
# Epoch 56: loss did not improve from 0.03887
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000001518582595e-15.
# 3/3 [==============================] - 6s 2s/step - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025 - lr: 1.0000e-14
# Epoch 57/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 57: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-15
# Epoch 58/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 58: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-15
# Epoch 59/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 59: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-15
# Epoch 60/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023
# Epoch 60: loss did not improve from 0.03887
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.0000001095066122e-16.
# 3/3 [==============================] - 6s 2s/step - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023 - lr: 1.0000e-15
# Epoch 61/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 61: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-16
# Epoch 62/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 62: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-16
# Epoch 63/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025
# Epoch 63: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025 - lr: 1.0000e-16
# Epoch 64/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041
# Epoch 64: loss did not improve from 0.03887
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.0000000830368326e-17.
# 3/3 [==============================] - 6s 2s/step - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-16
# Epoch 65/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 65: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-17
# Epoch 66/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 66: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-17
# Epoch 67/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043
# Epoch 67: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-17
# Epoch 68/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 68: loss did not improve from 0.03887
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.0000000664932204e-18.
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-17
# Epoch 69/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3130 - vxm_dense_transformer_loss: 0.3126 - vxm_dense_flow_loss: 0.0077
# Epoch 69: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.3130 - vxm_dense_transformer_loss: 0.3126 - vxm_dense_flow_loss: 0.0077 - lr: 1.0000e-18
# Epoch 70/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041
# Epoch 70: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-18
# Epoch 71/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 71: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-18
# Epoch 72/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023
# Epoch 72: loss did not improve from 0.03887
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.000000045813705e-19.
# 3/3 [==============================] - 6s 2s/step - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023 - lr: 1.0000e-18
# Epoch 73/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043
# Epoch 73: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-19
# Epoch 74/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 74: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-19
# Epoch 75/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 75: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-19
# Epoch 76/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0922 - vxm_dense_transformer_loss: 0.0920 - vxm_dense_flow_loss: 0.0026
# Epoch 76: loss did not improve from 0.03887
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.000000032889008e-20.
# 3/3 [==============================] - 6s 2s/step - loss: 0.0922 - vxm_dense_transformer_loss: 0.0920 - vxm_dense_flow_loss: 0.0026 - lr: 1.0000e-19
# Epoch 77/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 77: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-20
# Epoch 78/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 78: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-20
# Epoch 79/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043
# Epoch 79: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-20
# Epoch 80/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043
# Epoch 80: loss did not improve from 0.03887
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.0000000490448793e-21.
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-20
# Epoch 81/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041
# Epoch 81: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-21
# Epoch 82/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 82: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-21
# Epoch 83/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 83: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-21
# Epoch 84/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 84: loss did not improve from 0.03887
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.0000000692397185e-22.
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-21
# Epoch 85/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041
# Epoch 85: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1302 - vxm_dense_transformer_loss: 0.1300 - vxm_dense_flow_loss: 0.0041 - lr: 1.0000e-22
# Epoch 86/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 86: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-22
# Epoch 87/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043
# Epoch 87: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1658 - vxm_dense_transformer_loss: 0.1655 - vxm_dense_flow_loss: 0.0043 - lr: 1.0000e-22
# Epoch 88/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023
# Epoch 88: loss did not improve from 0.03887
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.0000000944832675e-23.
# 3/3 [==============================] - 6s 2s/step - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023 - lr: 1.0000e-22
# Epoch 89/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 89: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-23
# Epoch 90/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025
# Epoch 90: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025 - lr: 1.0000e-23
# Epoch 91/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025
# Epoch 91: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025 - lr: 1.0000e-23
# Epoch 92/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 92: loss did not improve from 0.03887
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.0000000787060494e-24.
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-23
# Epoch 93/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059
# Epoch 93: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2216 - vxm_dense_transformer_loss: 0.2213 - vxm_dense_flow_loss: 0.0059 - lr: 1.0000e-24
# Epoch 94/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 94: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-24
# Epoch 95/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042
# Epoch 95: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.1480 - vxm_dense_transformer_loss: 0.1478 - vxm_dense_flow_loss: 0.0042 - lr: 1.0000e-24
# Epoch 96/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060
# Epoch 96: loss did not improve from 0.03887
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.0000001181490946e-25.
# 3/3 [==============================] - 6s 2s/step - loss: 0.2394 - vxm_dense_transformer_loss: 0.2391 - vxm_dense_flow_loss: 0.0060 - lr: 1.0000e-24
# Epoch 97/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024
# Epoch 97: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0566 - vxm_dense_transformer_loss: 0.0565 - vxm_dense_flow_loss: 0.0024 - lr: 1.0000e-25
# Epoch 98/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023
# Epoch 98: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0389 - vxm_dense_transformer_loss: 0.0387 - vxm_dense_flow_loss: 0.0023 - lr: 1.0000e-25
# Epoch 99/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025
# Epoch 99: loss did not improve from 0.03887
# 3/3 [==============================] - 6s 2s/step - loss: 0.0744 - vxm_dense_transformer_loss: 0.0743 - vxm_dense_flow_loss: 0.0025 - lr: 1.0000e-25
# Epoch 100/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3130 - vxm_dense_transformer_loss: 0.3126 - vxm_dense_flow_loss: 0.0077
# Epoch 100: loss did not improve from 0.03887
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.0000001428009978e-26.
# 3/3 [==============================] - 6s 2s/step - loss: 0.3130 - vxm_dense_transformer_loss: 0.3126 - vxm_dense_flow_loss: 0.0077 - lr: 1.0000e-25
# --- 627.0782685279846 seconds ---

# %%
def plot_history(hist, loss_name='loss'):
    # Simple function to plot training history.
    plt.figure()
    plt.plot(hist.epoch, hist.history[loss_name], '.-')
    #plt.plot(hist.epoch, hist.history['disp_loss'], '.-')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

plot_history(hist)

# %%
nb_epochs = 2

# load model
vxm_model.load_weights('/content/drive/MyDrive/MIRA_Final_Project/dataset/results/Affine_BSpline_VM_train_75_test_25_epoch_100.keras')

# data generator on val data (copd4)
val_generator = vxm_data_generator(data_val, BATCH_SIZE_)
val_input, _ = next(val_generator)

# predict on validation data (copd4)
val_pred = vxm_model.predict(val_input)

# visualize
slices_2d = [f[0, :, :, 60, 0] for f in val_input + val_pred]
titles = ['moving image', 'fixed image', 'moved image', 'deformation field']

# Rotate all the plotted images by 90 degrees clockwise
slices_2d_rotated = [np.rot90(f, k=-1) for f in slices_2d]

ne.plot.slices(slices_2d_rotated, titles=titles, cmaps=['gray'], do_colorbars=True, width=10)

# Visualize the flow
val_pred_flow_rotated = np.rot90(val_pred[1][0, :, :, 60, 0:2].squeeze(), k=-1)
ne.plot.flow([val_pred_flow_rotated], width=5)
# Out:
# 1/1 [==============================] - 1s 1s/step
# (<Figure size 500x500 with 1 Axes>, [<Axes: >])

# %%
# Rotate images by 90 degrees clockwise
fixed_rotated = np.rot90(slices_2d[1], k=-1)  # Rotate fixed image
moved_rotated = np.rot90(slices_2d[2], k=-1)  # Rotate moved image

plt.figure()
plt.axis('off')

# Display fixed image in grayscale
plt.imshow(fixed_rotated, cmap='gray', alpha=1)

# Display moved image in 'jet' colormap with 20% transparency
plt.imshow(moved_rotated, cmap='jet', alpha=0.2)

plt.show()

# %%
def calculateTRE(landmarks_fixed, landmarks_moving, voxel_dimensions):

    # Taking into account the voxel size
    landmarks_moving = voxel_dimensions * landmarks_moving
    landmarks_fixed  = voxel_dimensions * landmarks_fixed

    # Calculated the squared difference (euclidean)
    tre = np.sqrt(np.sum((landmarks_fixed - landmarks_moving) ** 2,axis =1))

    # Calculating the mean and std tre
    mean_tre = np.mean(tre)
    std_tre = np.std(tre)

    return mean_tre, std_tre

# %%
def point_spatial_transformer(surface_points, trf, single=False):

    surface_pts_D = surface_points.get_shape().as_list()[-1]
    trf_D = trf.get_shape().as_list()[-1]
    assert surface_pts_D in [trf_D, trf_D + 1]

    if surface_pts_D == trf_D + 1:
        li_surface_pts = K.expand_dims(surface_points[..., -1], -1)
        surface_points = surface_points[..., :-1]

    fn = lambda x: ne.utils.interpn(x[0], x[1])
    diff = tf.map_fn(fn, [trf, surface_points], dtype=tf.float32)
    ret = surface_points + diff

    if surface_pts_D == trf_D + 1:
        ret = tf.concat((ret, li_surface_pts), -1)

    return ret

# %%
def after_registration(id, param, landmarks_moving, landmarks_fixed, voxel_spacing):

  # based on which COPD data you have selected, the dimensions are assigned
  if id == "1":
    sample_data = data[0:1,...]
    z_dim = 121

  elif id == "2":
    sample_data = data[1:2,...]
    z_dim = 102

  elif id == "3":
    sample_data = data[2:3,...]
    z_dim = 126

  elif id == "4":
    sample_data = data[3:4,...]
    z_dim = 126

  # data augmentation done on the data
  val_generator = vxm_data_generator(sample_data, batch_size = 1)
  val_input, _ = next(val_generator)

  val_pred = vxm_model.predict(val_input)

  out_results = val_pred[1].squeeze()
  factor = z_dim / out_results.shape[2]

  new_out = zoom(out_results,(2, 2, factor,1),order=1)

  data_tf = tf.convert_to_tensor(new_out, dtype=tf.float32)
  data_tf = K.expand_dims(data_tf, 0)

  # Transforming the fixed (inhale) landmark points and then comparing with the exisiting moving (exhale) landmark points
  landmarksF = tf.convert_to_tensor(landmarks_fixed, dtype=tf.float32)
  landmarksF = K.expand_dims(landmarksF, 0)

  transformed_points = point_spatial_transformer(landmarksF, data_tf)

  def tensor_to_array(array_value):
      return array_value.numpy()

  array = tensor_to_array(transformed_points)
  array = array.squeeze()

  # Calculating the TRE
  mean_tre , std_tre = calculateTRE(array, landmarks_moving, voxel_spacing)
  print('COPD{0} & {1:.2f} ({2:.2f})'.format(id, mean_tre , std_tre))

# %%
def save_landmark_points(id, param, landmarks_fixed, voxel_spacing):

   # based on which COPD data you have selected, the dimensions are assigned
  if id == "1":
    sample_data = data[0:1,...]
    z_dim = 121

  elif id == "2":
    sample_data = data[1:2,...]
    z_dim = 102

  elif id == "3":
    sample_data = data[2:3,...]
    z_dim = 126

  elif id == "4":
    sample_data = data[3:4,...]
    z_dim = 126


  # data augmentation done on the data
  val_generator = vxm_data_generator(sample_data, batch_size = 1)
  val_input, _ = next(val_generator)

  val_pred = vxm_model.predict(val_input)

  out_results = val_pred[1].squeeze()
  factor = z_dim / out_results.shape[2]
  if(id == 0):
    new_out = zoom(out_results,(1, 1, factor,1),order=1)
  else:
    new_out = zoom(out_results,(2, 2, factor,1),order=1)


  data_tf = tf.convert_to_tensor(new_out, dtype=tf.float32)
  data_tf = K.expand_dims(data_tf, 0)

  # Transforming the fixed (inhale) landmark points and then comparing with the exisiting moving (exhale) landmark points
  landmarksF = tf.convert_to_tensor(landmarks_fixed, dtype=tf.float32)
  landmarksF = K.expand_dims(landmarksF, 0)

  transformed_points = point_spatial_transformer(landmarksF, data_tf)

  def tensor_to_array(array_value):
      return array_value.numpy()

  array = tensor_to_array(transformed_points)
  array = array.squeeze()

  np.savetxt('/content/drive/MyDrive/MIRA_Final_Project/dataset/saved_data/t_copd{0}_300_iBH_xyz_r1.txt'.format(id), array)

# %%
data_file = "/content/drive/MyDrive/MIRA_Final_Project/dataset/results_affine_bspline_preprocessed/"

list_id = [1, 2, 3, 4]

for val_i in list_id:

  id = str(val_i)

  # Set this path to the file containing all the images
  path_to_data_dir = data_file

  path_to_data_dir = "{0}copd{1}/".format(path_to_data_dir,id)

  # Setting up the input parameters
  param = {}

  # Input Images
  param['inhale'] = path_to_data_dir + 'copd' + id + '/' + 'copd' + id + '_iBHCT.nii.gz'

  # Landmark Images Inhale and Exhale
  param['landmarks_inhale'] = path_to_data_dir + 'copd' + id + '/' + 'copd' + id + '_reg_transformed_points.txt'
  param['landmarks_exhale'] = path_to_data_dir + 'copd' + id + '/' + 'copd' + id + '_300_eBH_xyz_r1.txt'

  # Loading the inhale and exhale landmarks
  landmarks_moving = np.loadtxt(param['landmarks_exhale'])
  landmarks_fixed = np.loadtxt(param['landmarks_inhale'])

  # Getting the voxel spacing in the image
  voxel_spacing = nib.load(param['inhale']).header.get_zooms()

  after_registration(id, param, landmarks_moving, landmarks_fixed, voxel_spacing)
# Out:
# 1/1 [==============================] - 1s 594ms/step
# COPD1 & 1.55 (1.87)
# 1/1 [==============================] - 1s 504ms/step
# COPD2 & 4.21 (4.72)
# 1/1 [==============================] - 0s 492ms/step
# COPD3 & 1.27 (0.99)
# 1/1 [==============================] - 1s 518ms/step
# COPD4 & 1.71 (1.39)
